# %% [markdown]
# # ARTI 205 – Machine Learning
# ## Lab 2: Identifying ML Problems, Selecting Open Datasets, and Drawing a Methodology Diagram
#
# ### Task 1: Choosing an Open Dataset
#
# **Dataset Name:** Iris Dataset
#
# **Source:** UCI Machine Learning Repository
#
# **Dataset Type:** Tabular Dataset
#
# **File Format:** CSV
#
# **Machine Learning Task:** Classification

# %% [markdown]
# ### Task 2: Defining the Machine Learning Problem
#
# **Problem Type:** Classification
#
# **Target Variable:** Species
#
# **Features:**
# - Sepal Length
# - Sepal Width
# - Petal Length
# - Petal Width
#
# **Expected Output:** Iris flower species
#
# **Problem Statement:**
#
# The objective of this project is to develop a machine learning classification model that predicts the species of an iris flower based on its sepal and petal measurements.

# %%
import pandas as pd

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

columns = [
    "sepal_length",
    "sepal_width",
    "petal_length",
    "petal_width",
    "species"
]

df = pd.read_csv(url, names=columns)

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### Task 5: Short Written Summary
#
# **Dataset Name:** Iris Dataset
#
# **Dataset Description:**
#
# The Iris dataset is a tabular dataset containing measurements of iris flowers. It includes sepal length, sepal width, petal length, and petal width. The dataset contains three iris flower species: Iris-setosa, Iris-versicolor, and Iris-virginica.
#
# **Machine Learning Problem:**
#
# This project is a classification problem because the model is expected to predict the species of an iris flower based on its measurements.
#
# **Target Variable:**
#
# The target variable is `species`.
#
# **Features:**
#
# - `sepal_length`
# - `sepal_width`
# - `petal_length`
# - `petal_width`
#
# **Objective:**
#
# The objective of this project is to develop a machine learning classification model that predicts the species of an iris flower based on its sepal and petal measurements.
